# %%
import pyodbc
#Si no funciona en el prompt de anaconda -> pip install pyodbc
import pandas as pd

# %%
server='ULCLAB1031'
bd='CentroSalud'
conexion=pyodbc.connect(driver='{SQL server}',host=server,database=bd)
#conexion=pyodbc.connect(driver='{SQL server}',host=server,database=bd;UID={usuario};PWD={clave})
print("Conexion exitosa Microsoft SQL SERVER")
# Out:
# Conexion exitosa Microsoft SQL SERVER

# %%
pp=pd.read_sql("select * from Paciente where iidsexo='1'",conexion)
#conexion.close()

pp
# Out:
# C:\Users\UPN\AppData\Local\Temp\ipykernel_11708\2717223141.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pp=pd.read_sql("select * from Paciente where iidsexo='1'",conexion)
#     IIDPACIENTE    NOMBRE   APPATERNO  APMATERNO                  EMAIL  \
# 0             1      Elsa  Manríquez    Acevedo   mmanrique@hotmail.com
# 1             2   Enrique      Mejía     Romero      emejia@hotmail.com
# 2             3  Carolina       Ruiz    Aquiles       cruiz@hotmail.com
# 3             4      José     Acosta     Tordoya    jacosta@hotmail.com
# 4             5    Celina    Aguilar     Montoro   caguilar@hotmail.com
# 5             6      Irma       Jesus       Diaz     ijesus@hotmail.com
# 6             7    María      Fonseca    Aurelio   mfonseca@hotmail.com
# ...

# %%
pp1=pd.read_sql("select * from Paciente",conexion)
#conexion.close()

pp1

# %%
pp2=pd.read_sql("select * from Medicamento",conexion)
#conexion.close()

pp2

# %%
pp2=pd.read_sql("select * from Medicamento where precio>4",conexion)
#conexion.close()

pp2
# Out:
# C:\Users\UPN\AppData\Local\Temp\ipykernel_19012\4119347123.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pp2=pd.read_sql("select * from Medicamento where precio>4",conexion)
#    IIDMEDICAMENTO       NOMBRE CONCENTRACION  IIDFORMAFARMACEUTICA  PRECIO  \
# 0               1   CETIRIZINA          10MG                     1     5.0
# 1               7  PARACETAMOL           1MG                     1    10.0
# 2               8  AMOXICILINA          20MG                     2    10.0
#
#    STOCK      PRESENTACION  BHABILITADO
# 0     30  UNA TABLETA DE 5            1
# 1     15           EN CAJA            0
# 2      5             SOBRE            1

# %%
cursor = conexion.cursor()
cursor.execute("INSERT INTO dbo.TipoSangre(NOMBRE, BHABILITADO) VALUES ('AB positivo 2', '1')")
conexion.commit()
#conexion.close()

# %%
pp4=pd.read_sql("select * from TipoSangre",conexion)
pp4
# Out:
# C:\Users\UPN\AppData\Local\Temp\ipykernel_11708\1313858048.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pp4=pd.read_sql("select * from TipoSangre",conexion)
#     IIDTIPOSANGRE         NOMBRE  BHABILITADO
# 0               1     O negativo          1.0
# 1               2     O positivo          1.0
# 2               3     A negativo          1.0
# 3               4     A positivo          1.0
# 4               5     B negativo          1.0
# 5               6     B positivo          1.0
# 6               7    AB negativo          1.0
# 7               8    AB positivo          NaN
# 8              11  AB positivo 2          1.0
# 9              12  AB positivo 2          1.0
# 10             13  AB positivo 2          1.0
# 11             14  AB positivo 2          1.0

# %%
cursor = conexion.cursor()
cursor.execute("DELETE FROM dbo.TipoSangre WHERE iidtiposangre in(14,13,12,11)")
conexion.commit()

# %%
pp4=pd.read_sql("select * from TipoSangre",conexion)
pp4
# Out:
# C:\Users\UPN\AppData\Local\Temp\ipykernel_11708\1313858048.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pp4=pd.read_sql("select * from TipoSangre",conexion)
#    IIDTIPOSANGRE       NOMBRE  BHABILITADO
# 0              1   O negativo          1.0
# 1              2   O positivo          1.0
# 2              3   A negativo          1.0
# 3              4   A positivo          1.0
# 4              5   B negativo          1.0
# 5              6   B positivo          1.0
# 6              7  AB negativo          1.0
# 7              8  AB positivo          NaN

# %%
cursor = conexion.cursor()
cursor.execute("UPDATE dbo.TipoSangre SET bhabilitado='1' WHERE iidtiposangre='8'")
conexion.commit()

# %%
pp4=pd.read_sql("select * from TipoSangre",conexion)
pp4
conexion.close()
# Out:
# C:\Users\UPN\AppData\Local\Temp\ipykernel_11708\251242809.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pp4=pd.read_sql("select * from TipoSangre",conexion)
