# %%
#Gráficas
#Importamos matplotlib para gráficas de la siguiente forma.
import matplotlib.pyplot as plt
#Importamos numpy para manejar vectores y matrices
import numpy as np

# %%
# Definimos nuestra función de Ecuacion exponencial.
def f(x):
        return np.exp(-x ** 2)

# %%
#Creamos un vector con los puntos que le pasaremos a la funcion previamente creada.
x = np.linspace(-1, 5, num=30)

# %%
#Representeamos la función utilizando el objeto plt de matplotlib
plt.xlabel("Eje $x$")
plt.ylabel("$f(x)$")
plt.legend()
plt.title("Funcion $f(x)$")
plt.grid(True)
fig = plt.plot(x, f(x))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Grafico de puntos con matplotlib
N = 100
x1 = np.random.randn(N) #creando vector x
y1 = np.random.randn(N) #creando vector y

s = 50 + 50 * np.random.randn(N) #variable para modificar el tamaño(size)
c = np.random.randn(N) #variable para modificar el color(color)

plt.scatter(x1, y1, s=s, c=c, cmap=plt.cm.Blues) 
plt.grid(True)
plt.colorbar()

fig = plt.scatter(x1, y1)

# %%
#Generando el universo de datos
edades = [88, 80, 76, 72, 68, 56, 64, 60, 64, 68, 64, 68, 
         72, 76, 80, 84, 68, 80, 76, 72, 84, 80, 72, 76]

# %%
#Generando Histograma
plt.xlabel("edades")
plt.ylabel("repeticiones")
plt.title("Variable cuantitativa")
plt.hist(edades, bins=5)
plt.show()
